# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jianlins/BMI_NLP_2024/blob/main/Module%209%20Name%20Entity%20Recognition%20Using%20Deep%20Learning.ipynb)
#
# # Name Entity Recognition Using Deep Learning
#
# This week we will use a different demo dataset to identify patients' family history of colon cancer by differentiating whether the statement of colon cancer is referring to a patient or a patient's relative. This demo dataset was also created using MIMIC demo dataset used in previous BMI NLP class.
#
# This dataset will be somewhat more challenging than the previous one we used. If you're wondering why, I highly recommend taking a look at the actual annotations using Brat (as I demonstrated in class).

# %% [markdown]
# ## Download the dataset

# %%
# %%capture
# !wget https://github.com/jianlins/FHI_Hands_on/raw/master/data/cc_train.zip

# %%
# %%capture
# !wget https://github.com/jianlins/FHI_Hands_on/raw/master/img/cc_test.zip

# %%
# !ls
# Out:
# cc_test.zip  cc_train.zip  sample_data

# %%
# %%capture
# !unzip cc_train.zip -d cc_train

# %%
# %%capture
# !unzip cc_test.zip -d cc_test

# %%
# !ls
# Out:
# cc_test  cc_test.zip  cc_train	cc_train.zip  sample_data

# %% [markdown]
# ## Install & import the packages

# %%
# !pip install quicksectx git+https://github.com/medspacy/medspacy_io
# Out:
# Collecting git+https://github.com/medspacy/medspacy_io
#   Cloning https://github.com/medspacy/medspacy_io to /tmp/pip-req-build-37snx69q
#   Running command git clone --filter=blob:none --quiet https://github.com/medspacy/medspacy_io /tmp/pip-req-build-37snx69q
#   Resolved https://github.com/medspacy/medspacy_io to commit b8104f8a998c641da04aef6eaa00a2dd8cae5f6a
#   Preparing metadata (setup.py) ... done
# Collecting quicksectx
#   Downloading quicksectx-0.3.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.3/408.3 kB 5.8 MB/s eta 0:00:00
# Collecting Cython<=3.0.8,>=0.25 (from quicksectx)
#   Downloading Cython-3.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from medspacy-io==0.1.0.dev34) (4.9.4)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from medspacy-io==0.1.0.dev34) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.6.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.2.2->medspacy-io==0.1.0.dev34) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.2.2->medspacy-io==0.1.0.dev34) (2.1.5)
# Building wheels for collected packages: medspacy-io
#   Building wheel for medspacy-io (setup.py) ... done
#   Created wheel for medspacy-io: filename=medspacy_io-0.1.0.dev34-py3-none-any.whl size=27809 sha256=6323c94cd2d58e199430c76fff5dc920295aa4ebd632ac4629c51524816b228a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0_44n7ay/wheels/3a/2f/d8/74167cb59930a691d739931049d67fb3fa5e4ce048839ebbb6
# Successfully built medspacy-io
# Installing collected packages: Cython, quicksectx, medspacy-io
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.9
#     Uninstalling Cython-3.0.9:
#       Successfully uninstalled Cython-3.0.9
# Successfully installed Cython-3.0.8 medspacy-io-0.1.0.dev34 quicksectx-0.3.9

# %% [markdown]
# ## Import packages

# %%
from spacy.lang.en import English
from medspacy_io.reader import BratDocReader
from medspacy_io.reader import BratDirReader
import spacy
from pathlib import Path
from medspacy_io.vectorizer import Vectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report
import re
from spacy.tokens import Doc
from typing import List
import pandas as pd

# %% [markdown]
# ## Read data

# %%
config='''[entities]
FAM_COLON_CA_DOC
FAM_COLON_CA
ANATOM
NEGATED_DOC
COLON_CA
Pos_Doc
NEG_DOC
PastConcept
[attributes]
Negation	Arg:COLON_CA,	Value:affirm
Experiencer	Arg:COLON_CA,	Value:patient
Certainty	Arg:COLON_CA,	Value:certain
Note	Arg:FAM_COLON_CA|PossibleConcept|NegatedConcept|PastConcept
Temporality	Arg:COLON_CA,	Value:present
Section	Arg:COLON_CA,	Value:SourceDocumentInformation
[relations]
[events]'''

# %%
# The dataset files does not include schema configuration, let's create one
Path('annotation.conf').write_text(config)
# Out:
# 403

# %%
# set up the Brat reader
nlp=spacy.load("en_core_web_sm", disable=['ner'])
dir_reader = BratDirReader(nlp=nlp, support_overlap=False, recursive=True, schema_file=Path('annotation.conf'))
# Out:
# found annotation.conf file

# %%
train_docs= dir_reader.read(txt_dir='cc_train')
test_docs= dir_reader.read(txt_dir='cc_test')

# %% [markdown]
# ## Generate BIO tags
#
# We will reuse the spans_to_bio function from last week to first generate BIO tags. I

# %%
def spans_to_bio(doc:Doc, anno_types:List[str], abbr:bool=True)->str:
  """
  Converts spans in a spaCy Doc object to a BIO-formatted string, with an option
  to abbreviate the entity labels. It adds an empty line between sentences to improve
  readability.

  Parameters:
  - doc (Doc): The spaCy Doc object containing the text and its annotations, including
                entities and sentence boundaries.
  - anno_types (List[str]): A list of annotation types to include in the output. These
                            types should correspond to the keys in `doc.spans`.
  - abbr (bool, optional): If True, entity labels are abbreviated to their initials.
                            Defaults to True.

  Returns:
  - str: A string where each token is followed by its BIO tag (with the entity label if applicable),
          formatted as "token B-entity" or "token I-entity" for tokens within entities, and
          "token O" for tokens outside any entities. Sentences are separated by an empty line.
  """
  # Initialize a dictionary to hold BIO tags for each token index
  bio_tags = {token.i: 'O' for token in doc}  # Default to 'O' for outside any entity

  # Preprocess spans to assign BIO tags
  for anno_type in anno_types:
    for span in doc.ents:
      if span:  # Check if span is not empty
        label=span.label_
        if abbr:
          label=''.join([w[0] for w in label.split('_')])
        bio_tags[span.start] = f"B-{label}"  # Begin tag for the first token in the span
        for token in span[1:]:  # Inside tags for the rest of the tokens in the span
          bio_tags[token.i] = f"I-{label}"

  # Generate BIO format string
  bio_text = []
  bio_data={'sentence_id':[],'token':[],'lab':[]}
  for s,sent in enumerate(doc.sents):
    for i,token in enumerate(sent):
      # trim the whitespaces on both sides of a sentence
      if (i==0 or i==len(sent)-1) and str(token).strip()=='':
        bio_text.append('')
        continue
      elif str(token).strip()=='':
        # clean up extra whitespaces within a sentence.
        bio_text.append(f' \t{bio_tags[token.i]}')
        bio_data['lab'].append(bio_tags[token.i])
      else:
        bio_text.append(f"{token.text} {bio_tags[token.i]}")
        bio_data['lab'].append(bio_tags[token.i])
      bio_data['token'].append(token)
      bio_data['sentence_id'].append(s)
    bio_text.append('')  # Empty line between sentences
  return '\n'.join(bio_text), pd.DataFrame(bio_data)

# %%
# We will focus on two types of concepts here
data, df=spans_to_bio(train_docs[7], anno_types=['FAM_COLON_CA','COLON_CA'])

# %%
df[df['lab']!='O']
# Out:
#      sentence_id      token     lab
# 0              0  Admission  B-FCCD
# 929           44      colon   B-FCC
# 930           44         CA   I-FCC

# %% [markdown]
# ## Assigment 1
# Let's begin with a simpler task: train an NER model using the CRF approach and evaluate its performance.

# %% [markdown]
# ## Assigment 2
# Plot the distribution of all tags using a histogram, bar chart, or pie chart. Do you notice any issues? What steps could you take to potentially enhance performance? Please implement your solution here.

# %% [markdown]
# ## Assigment 3
# Implement a bi-LSTM model for this task.
# * Don't know what is bi-LSTM? --check the lecture recording of last deep learning module.
# * Don't know how to implement bi-LSTM? -- try chat with ChatGPT. I think you will learn how to communicate with ChatGPT more efficiently after you use it more or learn from others.

# %% [markdown]
# ## Assigment 4
# Use this [BERT model](https://huggingface.co/google-bert/bert-base-uncased) to implement a tokenclassifier for this NER task.
# You can follow the [token classification tutorial here](https://huggingface.co/docs/transformers/en/tasks/token_classification).
#
# **Note**: you will need to reimplement a different spans_to_bio function or make another function to align the labels. **Why**?
